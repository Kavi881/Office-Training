# %% [raw]
# Implement the following:-
#  loc,
# iloc,
# explicit method of filtering
# Implicit method filtering
# Query method

# %% [raw]
# Objective:
# The objective of this exercise is to understand and analyze flight-related data using essential DataFrame methods. The dataset contains parameters related to flight schedules, delays, and cancellations. This lab focuses on exploring and interpreting the data to uncover patterns and insights.
#
#
# 1. Data Overview
# Task: Identify the shape of the dataset (number of rows and columns).
# Method: Use a method to get the dimensions of the dataset.
# 2. Column Information
# Task: Display the column names, data types, and non-null values.
# Method: Use appropriate methods to describe the dataset structure.
# 3. Previewing Data
# Task: View the first and last few rows of the dataset.
# Method: Use methods to display the top and bottom rows of the dataset.
# 4. Handling Missing Data
# Task: Check for missing values in the dataset.
# Method: Use methods to identify null values and their counts.
# 5. Descriptive Statistics
# Task: Generate summary statistics for numerical columns, including mean, median, standard deviation, and percentiles.
# Method: Use statistical methods to compute descriptive statistics.
# 6. Filtering Data
# Task: Extract records where flights were delayed by more than 15 minutes or were canceled.
# Method: Apply filtering techniques on columns like DepDelay, ArrDelay, and Cancelled.
# 7. Grouping and Aggregation
# Task: Analyze the average delay for each airline (Carrier) or by airport.
# Method: Use grouping and aggregation methods to summarize the data.
# 8. Sorting
# Task: Sort the dataset by DepDelay in descending order to find the most delayed flights.
# Method: Use sorting methods for the analysis

# %%
import pandas as pd

# %%
Flight_data = pd.read_csv(r"C:\Users\Kavita Pant\Downloads\sample.csv")

# %%
Flight_data.shape
# Out:
# (271940, 20)

# %%
Flight_data.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'Carrier',
#        'OriginAirportID', 'OriginAirportName', 'OriginCity', 'OriginState',
#        'DestAirportID', 'DestAirportName', 'DestCity', 'DestState',
#        'CRSDepTime', 'DepDelay', 'DepDel15', 'CRSArrTime', 'ArrDelay',
#        'ArrDel15', 'Cancelled'],
#       dtype='object')

# %%
Flight_data
# Out:
#         Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 0       2013      9          16          1      DL            15304
# 1       2013      9          23          1      WN            14122
# 2       2013      9           7          6      AS            14747
# 3       2013      7          22          1      OO            13930
# 4       2013      5          16          4      DL            13931
# ...      ...    ...         ...        ...     ...              ...
# 271935  2013      9          20          5      VX            13204
# 271936  2013      4          19          5      FL            10397
# 271937  2013     10          26          6      WN            12191
# 271938  2013      5           7          2      HA            13830
# 271939  2013      6          11          2      UA            14771
#
#                                OriginAirportName     OriginCity OriginState  \
# ...

# %%
#View the first and last few rows of the dataset.
Flight_data.head(5)
# Out:
#    Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 0  2013      9          16          1      DL            15304
# 1  2013      9          23          1      WN            14122
# 2  2013      9           7          6      AS            14747
# 3  2013      7          22          1      OO            13930
# 4  2013      5          16          4      DL            13931
#
#               OriginAirportName  OriginCity OriginState  DestAirportID  \
# 0           Tampa International       Tampa          FL          12478
# 1      Pittsburgh International  Pittsburgh          PA          13232
# 2  Seattle/Tacoma International     Seattle          WA          11278
# 3  Chicago O'Hare International     Chicago          IL          11042
# 4         Norfolk International     Norfolk          VA          10397
#
#                             DestAirportName    DestCity DestState  CRSDepTime  \
# ...

# %%
Flight_data.tail(5)
# Out:
#         Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 271935  2013      9          20          5      VX            13204
# 271936  2013      4          19          5      FL            10397
# 271937  2013     10          26          6      WN            12191
# 271938  2013      5           7          2      HA            13830
# 271939  2013      6          11          2      UA            14771
#
#                                OriginAirportName     OriginCity OriginState  \
# 271935                     Orlando International        Orlando          FL
# 271936  Hartsfield-Jackson Atlanta International        Atlanta          GA
# 271937                           William P Hobby        Houston          TX
# 271938                           Kahului Airport        Kahului          HI
# 271939               San Francisco International  San Francisco          CA
#
#         DestAirportID                                    DestAirportName  \
# ...

# %%
#Check for missing values in the dataset.
Flight_data.isnull()
# Out:
#          Year  Month  DayofMonth  DayOfWeek  Carrier  OriginAirportID  \
# 0       False  False       False      False    False            False
# 1       False  False       False      False    False            False
# 2       False  False       False      False    False            False
# 3       False  False       False      False    False            False
# 4       False  False       False      False    False            False
# ...       ...    ...         ...        ...      ...              ...
# 271935  False  False       False      False    False            False
# 271936  False  False       False      False    False            False
# 271937  False  False       False      False    False            False
# 271938  False  False       False      False    False            False
# 271939  False  False       False      False    False            False
#
#         OriginAirportName  OriginCity  OriginState  DestAirportID  \
# ...

# %%
#identify null values and their counts
Flight_data.isnull().sum()
# Out:
# Year                    0
# Month                   0
# DayofMonth              0
# DayOfWeek               0
# Carrier                 0
# OriginAirportID         0
# OriginAirportName       0
# OriginCity              0
# OriginState             0
# DestAirportID           0
# DestAirportName         0
# DestCity                0
# DestState               0
# CRSDepTime              0
# DepDelay                0
# DepDel15             2761
# CRSArrTime              0
# ArrDelay                0
# ArrDel15                0
# Cancelled               0
# dtype: int64

# %%
#Task: Generate summary statistics for numerical columns, including mean, median, standard deviation, and percentiles.

# %%
mean_value = Flight_data[["CRSDepTime", "DepDelay", "CRSArrTime",  "ArrDelay", "Cancelled"]].mean()
mean_value
# Out:
# CRSDepTime    1325.498713
# DepDelay        10.350449
# CRSArrTime    1505.477819
# ArrDelay         6.496650
# Cancelled        0.010723
# dtype: float64

# %%
median_value = Flight_data[["CRSDepTime", "DepDelay", "CRSArrTime",  "ArrDelay", "Cancelled"]].median()
median_value
# Out:
# CRSDepTime    1320.0
# DepDelay        -1.0
# CRSArrTime    1529.0
# ArrDelay        -3.0
# Cancelled        0.0
# dtype: float64

# %%
standard_deviation_value = Flight_data[["CRSDepTime", "DepDelay", "CRSArrTime",  "ArrDelay", "Cancelled"]].std()
standard_deviation_value
# Out:
# CRSDepTime    470.748546
# DepDelay       35.673710
# CRSArrTime    493.204020
# ArrDelay       38.230331
# Cancelled       0.102995
# dtype: float64

# %%
percentile_value = Flight_data[["CRSDepTime", "DepDelay", "CRSArrTime",  "ArrDelay", "Cancelled"]].quantile(0.25)
percentile_value
# Out:
# CRSDepTime     920.0
# DepDelay        -4.0
# CRSArrTime    1119.0
# ArrDelay       -11.0
# Cancelled        0.0
# Name: 0.25, dtype: float64

# %%
percentile_value1 = Flight_data[["CRSDepTime", "DepDelay", "CRSArrTime",  "ArrDelay", "Cancelled"]].quantile(0.75)
percentile_value1
# Out:
# CRSDepTime    1725.0
# DepDelay         9.0
# CRSArrTime    1918.0
# ArrDelay        10.0
# Cancelled        0.0
# Name: 0.75, dtype: float64

# %% [raw]
# 6. Filtering Data
# Task: Extract records where flights were delayed by more than 15 minutes or were canceled.
# Method: Apply filtering techniques on columns like DepDelay, ArrDelay, and Cancelled.

# %%
Flight_delay_15mins= Flight_data[(Flight_data["DepDel15"] == 1)]
Flight_canceled= Flight_data[(Flight_data["Cancelled"] == 1)]

# %%
delayed_or_cancelled =pd.concat([Flight_delay_15mins,Flight_canceled],axis=0)
delayed_or_cancelled
# Out:
#         Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 3       2013      7          22          1      OO            13930
# 5       2013      7          28          7      UA            12478
# 9       2013      5          12          7      UA            12478
# 13      2013      7          17          3      AA            11298
# 16      2013     10          31          4      MQ            11057
# ...      ...    ...         ...        ...     ...              ...
# 271410  2013      8           5          1      WN            14831
# 271607  2013      6          18          2      EV            14100
# 271634  2013      5           8          3      AA            11298
# 271671  2013     10           8          2      WN            12892
# 271885  2013      5          15          3      US            14771
#
#                               OriginAirportName         OriginCity  \
# 3                  Chicago O'Hare International            Chicago
# ...

# %% [raw]
# 7. Grouping and Aggregation
# Task: Analyze the average delay for each airline (Carrier) or by airport.
# Method: Use grouping and aggregation methods to summarize the data.

# %%
average_delay_by_origin_airport= Flight_data.groupby(Flight_data.Carrier)["DepDelay"].mean()
average_delay_by_origin_airport
# Out:
# Carrier
# 9E     9.644689
# AA    12.114470
# AS     0.711857
# B6    12.706523
# DL     7.130840
# EV    14.031160
# F9    10.888355
# FL    10.551529
# HA     1.334753
# MQ    14.797882
# OO     7.623694
# UA    12.265440
# US     4.920037
# VX    14.120124
# WN    12.597017
# YV     8.772345
# Name: DepDelay, dtype: float64

# %% [markdown]
# 8. Sorting
# Task: Sort the dataset by DepDelay in descending order to find the most delayed flights.
# Method: Use sorting methods for the analysis

# %%
delayed_flights = Flight_data.sort_values('DepDelay', ascending=False)
delayed_flights
# Out:
#         Year  Month  DayofMonth  DayOfWeek Carrier  OriginAirportID  \
# 180503  2013      4           3          3      AA            10397
# 251813  2013      7           2          2      AA            12889
# 255631  2013      6          17          1      AA            14771
# 32883   2013      4           1          1      AA            13871
# 121919  2013      4          17          3      AA            14492
# ...      ...    ...         ...        ...     ...              ...
# 114556  2013      5           3          5      AS            15376
# 156662  2013      4           2          2      YV            14307
# 132362  2013      4          11          4      EV            10397
# 7989    2013      5          23          4      EV            11292
# 113842  2013     10          11          5      F9            10821
#
#                                         OriginAirportName      OriginCity  \
# 180503           Hartsfield-Jackson Atlanta International         Atlanta
# ...
